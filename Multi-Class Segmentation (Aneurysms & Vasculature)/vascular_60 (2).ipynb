# %% [markdown]
# This notebook contains code relating to section 5.4: multiclass bounding box segmentation. In particular, this is for the segmentation of 60-by-60-pixel patches.

# %% [markdown]
# # Installations

# %%
pip -q install wandb

# %%
pip -q install tensorflow_addons

# %%
import numpy as np
import nibabel
import os
import tensorflow as tf
import matplotlib.pyplot as plt

import albumentations as A

from __future__ import print_function

from skimage.transform import resize
from skimage.io import imsave
from skimage.segmentation import mark_boundaries
from skimage.exposure import rescale_intensity
from skimage import io
from scipy.spatial.distance import directed_hausdorff

import keras
from keras.models import Model, Sequential
from tensorflow.keras.layers.experimental import preprocessing
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose, Dropout, BatchNormalization, Flatten, Dense
from tensorflow.keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as K
from keras.callbacks import History
from tensorflow.keras.utils import plot_model
from tensorflow_addons.optimizers import AdamW
from tensorflow.keras import layers

import wandb
from wandb.keras import WandbCallback

from tqdm.auto import tqdm

os.getcwd()
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q git+https://github.com/tensorflow/examples.git

from tensorflow_examples.models.pix2pix import pix2pix

# %%
def get_tpu_strategy():
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver(
            tpu="grpc://" + os.environ["COLAB_TPU_ADDR"]
        )  # TPU detection
        print("Running on TPU ", tpu.cluster_spec().as_dict()["worker"])
    except ValueError:
        raise BaseException("ERROR: Not connected to a TPU runtime")

    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    return tf.distribute.TPUStrategy(tpu)

# %%
tpu_strategy = get_tpu_strategy()
# Out:
# Running on TPU  ['10.55.228.210:8470']
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# WARNING:tensorflow:TPU system grpc://10.55.228.210:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.55.228.210:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.55.228.210:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.55.228.210:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
# give permission to read data from google cloud bucket
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# # Functions for loading data in TFRecords format

# %%
def _parse_image_function(example_proto):

    """
    Reads from TFRecord file
    Returns a tf.train.Example object (can be read like a dictionary)
    """

    image_feature_description = {

        "image_raw": tf.io.FixedLenFeature([60 * 60], tf.float32),
        "mask_raw": tf.io.FixedLenFeature([60 * 60], tf.int64),
    }

    # Parse the input tf.train.Example proto using the dictionary above.
    return tf.io.parse_single_example(example_proto, image_feature_description)


def _unpack_proto(example_proto):

    """
    Extract image and mask from example_proto object
    """

    image = example_proto["image_raw"]
    image = tf.reshape(image, [60, 60, 1])

    mask = example_proto["mask_raw"]
    mask = tf.reshape(mask, [60, 60])

    return image, mask

# %%
### Data Augmentation

def _unpack_proto_aug(example_proto):

    """
    Extract image and mask from example_proto object
    """

    image = example_proto["image_raw"]
    image = tf.reshape(image, [60, 60, 1])

    mask = example_proto["mask_raw"]
    mask = tf.reshape(mask, [60, 60])

    # DATA AUGMENTATION
    if tf.random.uniform(()) > 0.5:
      image = tf.image.flip_left_right(image)
      mask = tf.image.flip_left_right(tf.expand_dims(mask, [2]))
      mask = tf.squeeze(mask)

    if tf.random.uniform(()) > 0.5:
      image = tf.image.rot90(image)
      mask = tf.image.rot90(tf.expand_dims(mask, [2]))
      mask = tf.squeeze(mask)

    return image, mask

# %%
def optimise_dataset(ds):

  """
  Improve performance of tensorflow dataset
  """

  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  # ds = ds.cache()
  return ds

def prepare_data(ds, shuffle=True):
  """
  Normalise, batch, shuffle and optimise the dataset
  """
  # ds = normalise(ds)
  if shuffle:
    ds = ds.shuffle(5000)
  batch_size = 8 * tpu_strategy.num_replicas_in_sync # 16*8 (tpu_strategy.num_replicas_in_sync value shown in output of previous cell)
  ds = ds.batch(batch_size, drop_remainder=True)
  ds = optimise_dataset(ds)
  return ds

def to_3_channels(image, mask):
  img_shape = (60, 60)
  image = tf.reshape(tf.repeat(image, 3), (*img_shape, 3))
  # mask = tf.reshape(tf.repeat(mask, 3), (*img_shape, 3))
  return image, mask

# %%
def add_sample_weights(image, mask):
  # The weights for each class, with the constraint that:
  #     sum(class_weights) == 1.0
  class_weights = tf.constant([1.0, 10.0, 20.0])
  class_weights = class_weights/tf.reduce_sum(class_weights)

  # Create an image of `sample_weights` by using the label at each pixel as an 
  # index into the `class weights` .
  sample_weights = tf.gather(class_weights, indices=tf.cast(mask, tf.int32))

  return image, mask, sample_weights

# %% [markdown]
# # Load training & validation data

# %%
train_nonempty_gcs_pattern = "gs://vascular_multiclass_method2_step2_60/train_non_empty*"
train_nonempty_filenames = tf.io.gfile.glob(train_nonempty_gcs_pattern)

train_nonempty_ds = tf.data.TFRecordDataset(train_nonempty_filenames)
train_nonempty_ds = train_nonempty_ds.map(_parse_image_function)
train_nonempty_ds = train_nonempty_ds.map(_unpack_proto_aug)
train_nonempty_ds = train_nonempty_ds.map(to_3_channels)

train_ds = prepare_data(train_nonempty_ds)
# train_ds = train_ds.map(add_sample_weights).element_spec

# %%
for images, masks in train_ds.take(1):  # only take first element of dataset
      numpy_images = images.numpy()
      numpy_masks = masks.numpy()

numpy_images.shape, numpy_masks.shape
# Out:
# ((64, 60, 60, 3), (64, 60, 60))

# %%
val_nonempty_gcs_pattern = "gs://vascular_multiclass_method2_step2_60/val_non_empty*"
val_nonempty_filenames = tf.io.gfile.glob(val_nonempty_gcs_pattern)

val_nonempty_ds = tf.data.TFRecordDataset(val_nonempty_filenames)
val_nonempty_ds = val_nonempty_ds.map(_parse_image_function)
val_nonempty_ds = val_nonempty_ds.map(_unpack_proto)
val_nonempty_ds = val_nonempty_ds.map(to_3_channels)

val_ds = prepare_data(val_nonempty_ds.repeat())

# %%
for images, masks in val_ds.take(1):  # only take first element of dataset
      numpy_images = images.numpy()
      numpy_masks = masks.numpy()

numpy_images.shape, numpy_masks.shape
# Out:
# ((64, 60, 60, 3), (64, 60, 60))

# %% [markdown]
# # Display Images

# %%
batch_num = 1
img_num = 5

for images, masks in train_ds.take(batch_num):  # only take first element of dataset
  numpy_images = images.numpy()
  numpy_masks = masks.numpy()

# %%
test_mask = numpy_masks[30]
test_mask.shape
# Out:
# (60, 60)

# %%
plt.imshow(test_mask==2, cmap='gray')

# %%
img_num = 30

plt.subplot(1,2,1)
plt.imshow(numpy_images[img_num], cmap='gray')
plt.title('Img')

plt.subplot(1,2,2)
plt.imshow(numpy_masks[img_num], cmap='gray')
plt.title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %% [markdown]
# # Loss Function

# %%
# return our metric and loss

with tpu_strategy.scope():

  def dice_coef(y_true, y_pred, smooth=1e-16):
    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)

    return (2* intersection + smooth)/(K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


  def dice_coef_multiclass(y_true, y_pred, output_channels=3):
    dice_tot = 0

    for index in range(0, output_channels): # calculate dice coefficient for classes 1 & 2 (aneurysms & vasculature, not background)
        dice_tot += dice_coef(y_true==index, y_pred[:,:,:,index])

    return dice_tot/(output_channels) # take average dice


  def dice_loss_multiclass(y_true, y_pred, output_channels=3):
    
    dice = dice_coef_multiclass(y_true, y_pred)

    return (1 - dice) # take average dice


  def dice_coef_loss(y_true, y_pred):
    return (1.0 - dice_coef(y_true, y_pred))


  def mixed_loss(y_true, y_pred):

    y_true_f = tf.cast(K.flatten(y_true), tf.float32)
    y_pred_f = K.flatten(y_pred)

    bce = tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f, from_logits=True)
    dice = dice_coef(y_true, y_pred)

    return bce + (1.0 - dice)

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## Pre-trained model: original

# %%
def rescale_output(y_pred):

  y_pred = tf.clip_by_value(y_pred, clip_value_min=0., clip_value_max=1.) # force values to be between 0 and 2

  return y_pred

# %%
with tpu_strategy.scope(): 

  def unet_model(output_channels):

    inputs = tf.keras.layers.Input(shape=[60, 60, 3])
    resize_layer = tf.keras.layers.Lambda(lambda img: tf.image.resize(img, (96, 96)))
    x = resize_layer(inputs)

    # # Downsampling through the model
    base_model = tf.keras.applications.MobileNetV2(input_shape=[96, 96, 3], include_top=False) # ImageNet weights only work with 3 channel images

    # # adding regularization
    # penalty = 0.001
    # regularizer = tf.keras.regularizers.l2(penalty)

    # for layer in base_model.layers:
    #     for attr in ['kernel_regularizer']:
    #         if hasattr(layer, attr):
    #           setattr(layer, attr, regularizer)

    #  # When we change the layers attributes, the change only happens in the model config file
    # model_json = base_model.to_json()

    # # Save the weights before reloading the model.
    # weights_path = "/content/drive/My Drive/Masters Project/Vascular Segmentation/Model Weights/test5.h5"
    # # weights_path = os.path.join(weights_path, 'test1.h5')
    # base_model.save_weights(weights_path)

    # # load the model from the config
    # base_model = tf.keras.models.model_from_json(model_json)
    
    # # Reload the model weights
    # base_model.load_weights(weights_path, by_name=True)

    # Use the activations of these layers
    layer_names = [
        'block_1_expand_relu',   # 48x48
        'block_3_expand_relu',   # 24x24
        'block_6_expand_relu',   # 12x12
        'block_13_expand_relu',  # 6x6
        'block_16_project',      # 3x3
    ]
    base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

    # # Create the feature extraction model
    down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)

    down_stack.trainable = False

    up_stack = [
        pix2pix.upsample(512, 3),  # 4x4 -> 8x8
        pix2pix.upsample(256, 3),  # 8x8 -> 16x16
        pix2pix.upsample(128, 3),  # 16x16 -> 32x32
        pix2pix.upsample(64, 3),   # 32x32 -> 64x64
    ]

    skips = down_stack(x)
    x = skips[-1] # final output of encoder
    skips = reversed(skips[:-1]) # all outputs of encoder except final, reversed
    # Upsampling and establishing the skip connections
    
    for up, skip in zip(up_stack, skips):
      x = up(x) # pass output of encoder through decoder (iterates through outputs of decoder)
      concat = tf.keras.layers.Concatenate() 
      x = concat([x, skip]) # cross-link: output of decoder concatenated with encoder output
    # This is the last layer of the model
    last = tf.keras.layers.Conv2DTranspose(
        output_channels, 3, strides=2,
        padding='same')  #64x64 -> 128x128

    normalise_output = tf.keras.layers.Lambda(rescale_output)

    x = last(x)
    shrinking_layer = tf.keras.layers.Lambda(lambda img: tf.image.resize(img, (60, 60)))
    x = shrinking_layer(x)
    # x = tf.keras.activations.softmax(x)
    # x = normalise_output(x)

    return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# # Load top-performing model

# %%
model = keras.models.load_model("/content/drive/My Drive/Masters Project/Vascular Segmentation/Model Weights/Vessel seg 60/lr=1e-3.4.h5", custom_objects={'dice_loss_multiclass': dice_loss_multiclass, 'dice_coef_multiclass': dice_coef_multiclass})

# %% [markdown]
# # Find Optimal Learning Rate

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = dice_coef_multiclass

model = unet_model(output_channels=3)
model.compile(optimizer=Adam(), loss=loss, metrics=metrics)

initial_weights = model.get_weights()
len(initial_weights)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_96_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step
# 273

# %%
def find_learning_rate(num_rates=50):
    rates = np.logspace(-5, -1, num=num_rates)
    img, label = list(train_ds.take(1))[0]
    losses = []
    for rate in tqdm(rates):

          model.compile(optimizer=Adam(learning_rate=rate), loss=loss, metrics=metrics)
          model.set_weights(initial_weights)
          model.fit(img, label, epochs=5, verbose=0)
          losses.append(model.history.history['loss'][-1])
    return losses, rates

losses, rates = find_learning_rate(50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.plot(np.log10(rates), np.clip(losses, 0, 2))
plt.title('Sparse Categorical \n cross-entropy loss \n for a variety of learning rates', size=16)
plt.xlabel('\n Learning rate exponent', size=16)
plt.ylabel('Sparse categorical \n cross-entropy loss \n', size=16)
plt.xticks(size=12)
plt.yticks(size=12)
# Out:
# (array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25]),
#  <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# # Learning Rate Scheduling & Early Stopping

# %%
def build_learning_rate_cycler(
    lr_start=1e-5,
    lr_max=5e-5,
    lr_min=1e-6,
    lr_rampup_epochs=10,
    lr_sustain_epochs=2,
    lr_exp_decay=0.9,
):
    lr_max = lr_max

    def lrfn(epoch):
        if epoch < lr_rampup_epochs:
            lr = (lr_max - lr_start) / lr_rampup_epochs * epoch + lr_start
        elif epoch < lr_rampup_epochs + lr_sustain_epochs:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) * lr_exp_decay ** (
                epoch - lr_rampup_epochs - lr_sustain_epochs
            ) + lr_min
        return lr

    return lrfn

lr_cycler = build_learning_rate_cycler(
          lr_start=1e-5,
          lr_max=1e-2,
          lr_min=1e-6,
          lr_rampup_epochs=20,
          lr_sustain_epochs=0,
          lr_exp_decay=0.9,
      )

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                    monitor='val_loss',
                    patience=20,
                    restore_best_weights=True,
                    mode='auto',
                )

# %% [markdown]
# # Training

# %%
with tpu_strategy.scope():

  model = unet_model(output_channels=3) # 1 output channel per class (background, vessels, aneurysms)

  learning_rate = 10**(-3.4)
  loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  metrics = dice_coef_multiclass

  model.compile(optimizer=Adam(learning_rate=learning_rate),
                loss=loss,
                metrics=metrics)

  EPOCHS = 200

# train on aneurysm-positive only
  history = model.fit(
      train_ds.map(add_sample_weights).repeat(),
      epochs=EPOCHS,
      steps_per_epoch=10,
      validation_data=val_ds.repeat(),
      validation_steps=1, callbacks = [early_stopping]) # , tf.keras.callbacks.LearningRateScheduler(lr_cycler, verbose=1)

  save_model_path = "/content/drive/My Drive/Masters Project/Vascular Segmentation/Model Weights/Vessel seg 60"
  model.save(os.path.join(save_model_path, 'lr=1e-3.4.h5'))
# Out:
# Epoch 1/200
# 10/10 [==============================] - 18s 729ms/step - loss: 0.0245 - dice_coef_multiclass: 0.3693 - val_loss: 0.2066 - val_dice_coef_multiclass: 0.4049
# Epoch 2/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0147 - dice_coef_multiclass: 0.4218 - val_loss: 0.1227 - val_dice_coef_multiclass: 0.4438
# Epoch 3/200
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0120 - dice_coef_multiclass: 0.4585 - val_loss: 0.0865 - val_dice_coef_multiclass: 0.4676
# Epoch 4/200
# 10/10 [==============================] - 2s 216ms/step - loss: 0.0101 - dice_coef_multiclass: 0.4782 - val_loss: 0.0714 - val_dice_coef_multiclass: 0.4833
# Epoch 5/200
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0093 - dice_coef_multiclass: 0.4861 - val_loss: 0.0627 - val_dice_coef_multiclass: 0.4874
# Epoch 6/200
# 10/10 [==============================] - 2s 194ms/step - loss: 0.0088 - dice_coef_multiclass: 0.4860 - val_loss: 0.0558 - val_dice_coef_multiclass: 0.4933
# Epoch 7/200
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0083 - dice_coef_multiclass: 0.4868 - val_loss: 0.0509 - val_dice_coef_multiclass: 0.4960
# Epoch 8/200
# 10/10 [==============================] - 2s 208ms/step - loss: 0.0078 - dice_coef_multiclass: 0.4875 - val_loss: 0.0530 - val_dice_coef_multiclass: 0.4958
# Epoch 9/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0076 - dice_coef_multiclass: 0.4883 - val_loss: 0.0466 - val_dice_coef_multiclass: 0.4956
# Epoch 10/200
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0073 - dice_coef_multiclass: 0.4896 - val_loss: 0.0430 - val_dice_coef_multiclass: 0.5004
# Epoch 11/200
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0069 - dice_coef_multiclass: 0.4901 - val_loss: 0.0468 - val_dice_coef_multiclass: 0.4958
# Epoch 12/200
# 10/10 [==============================] - 2s 171ms/step - loss: 0.0070 - dice_coef_multiclass: 0.4898 - val_loss: 0.0404 - val_dice_coef_multiclass: 0.5017
# Epoch 13/200
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0068 - dice_coef_multiclass: 0.4879 - val_loss: 0.0426 - val_dice_coef_multiclass: 0.4951
# Epoch 14/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0065 - dice_coef_multiclass: 0.4887 - val_loss: 0.0362 - val_dice_coef_multiclass: 0.5037
# Epoch 15/200
# 10/10 [==============================] - 2s 181ms/step - loss: 0.0065 - dice_coef_multiclass: 0.4859 - val_loss: 0.0382 - val_dice_coef_multiclass: 0.4980
# Epoch 16/200
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0063 - dice_coef_multiclass: 0.4883 - val_loss: 0.0343 - val_dice_coef_multiclass: 0.5055
# Epoch 17/200
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0062 - dice_coef_multiclass: 0.4903 - val_loss: 0.0366 - val_dice_coef_multiclass: 0.5009
# Epoch 18/200
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0061 - dice_coef_multiclass: 0.4901 - val_loss: 0.0351 - val_dice_coef_multiclass: 0.4949
# Epoch 19/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.0062 - dice_coef_multiclass: 0.4871 - val_loss: 0.0391 - val_dice_coef_multiclass: 0.4947
# Epoch 20/200
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0058 - dice_coef_multiclass: 0.4875 - val_loss: 0.0357 - val_dice_coef_multiclass: 0.4998
# Epoch 21/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0058 - dice_coef_multiclass: 0.4888 - val_loss: 0.0355 - val_dice_coef_multiclass: 0.4985
# Epoch 22/200
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0056 - dice_coef_multiclass: 0.4887 - val_loss: 0.0344 - val_dice_coef_multiclass: 0.4993
# Epoch 23/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0055 - dice_coef_multiclass: 0.4888 - val_loss: 0.0344 - val_dice_coef_multiclass: 0.4989
# Epoch 24/200
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0056 - dice_coef_multiclass: 0.4876 - val_loss: 0.0346 - val_dice_coef_multiclass: 0.4988
# Epoch 25/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0054 - dice_coef_multiclass: 0.4869 - val_loss: 0.0354 - val_dice_coef_multiclass: 0.4963
# Epoch 26/200
# 10/10 [==============================] - 2s 215ms/step - loss: 0.0054 - dice_coef_multiclass: 0.4881 - val_loss: 0.0340 - val_dice_coef_multiclass: 0.4982
# Epoch 27/200
# 10/10 [==============================] - 1s 133ms/step - loss: 0.0053 - dice_coef_multiclass: 0.4860 - val_loss: 0.0312 - val_dice_coef_multiclass: 0.5036
# Epoch 28/200
# 10/10 [==============================] - 2s 194ms/step - loss: 0.0053 - dice_coef_multiclass: 0.4887 - val_loss: 0.0302 - val_dice_coef_multiclass: 0.5032
# Epoch 29/200
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0052 - dice_coef_multiclass: 0.4846 - val_loss: 0.0371 - val_dice_coef_multiclass: 0.4929
# Epoch 30/200
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0052 - dice_coef_multiclass: 0.4912 - val_loss: 0.0335 - val_dice_coef_multiclass: 0.5036
# Epoch 31/200
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0049 - dice_coef_multiclass: 0.4885 - val_loss: 0.0337 - val_dice_coef_multiclass: 0.5040
# Epoch 32/200
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0051 - dice_coef_multiclass: 0.4902 - val_loss: 0.0326 - val_dice_coef_multiclass: 0.5034
# Epoch 33/200
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0051 - dice_coef_multiclass: 0.4860 - val_loss: 0.0380 - val_dice_coef_multiclass: 0.4826
# Epoch 34/200
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0051 - dice_coef_multiclass: 0.4883 - val_loss: 0.0383 - val_dice_coef_multiclass: 0.4903
# Epoch 35/200
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0049 - dice_coef_multiclass: 0.4860 - val_loss: 0.0341 - val_dice_coef_multiclass: 0.4993
# Epoch 36/200
# 10/10 [==============================] - 1s 149ms/step - loss: 0.0048 - dice_coef_multiclass: 0.4878 - val_loss: 0.0312 - val_dice_coef_multiclass: 0.5104
# Epoch 37/200
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0049 - dice_coef_multiclass: 0.4894 - val_loss: 0.0379 - val_dice_coef_multiclass: 0.5018
# Epoch 38/200
# 10/10 [==============================] - 1s 148ms/step - loss: 0.0048 - dice_coef_multiclass: 0.4881 - val_loss: 0.0392 - val_dice_coef_multiclass: 0.4952
# Epoch 39/200
# 10/10 [==============================] - 2s 224ms/step - loss: 0.0046 - dice_coef_multiclass: 0.4892 - val_loss: 0.0353 - val_dice_coef_multiclass: 0.5021
# Epoch 40/200
# 10/10 [==============================] - 1s 131ms/step - loss: 0.0047 - dice_coef_multiclass: 0.4883 - val_loss: 0.0354 - val_dice_coef_multiclass: 0.5034
# Epoch 41/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0044 - dice_coef_multiclass: 0.4895 - val_loss: 0.0352 - val_dice_coef_multiclass: 0.4978
# Epoch 42/200
# 10/10 [==============================] - 1s 138ms/step - loss: 0.0046 - dice_coef_multiclass: 0.4872 - val_loss: 0.0357 - val_dice_coef_multiclass: 0.5098
# Epoch 43/200
# 10/10 [==============================] - 3s 287ms/step - loss: 0.0045 - dice_coef_multiclass: 0.4873 - val_loss: 0.0373 - val_dice_coef_multiclass: 0.5049
# Epoch 44/200
# 10/10 [==============================] - 2s 176ms/step - loss: 0.0044 - dice_coef_multiclass: 0.4873 - val_loss: 0.0335 - val_dice_coef_multiclass: 0.5229
# Epoch 45/200
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0043 - dice_coef_multiclass: 0.4875 - val_loss: 0.0297 - val_dice_coef_multiclass: 0.5243
# Epoch 46/200
# 10/10 [==============================] - 2s 195ms/step - loss: 0.0045 - dice_coef_multiclass: 0.4894 - val_loss: 0.0331 - val_dice_coef_multiclass: 0.5166
# Epoch 47/200
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0044 - dice_coef_multiclass: 0.4909 - val_loss: 0.0365 - val_dice_coef_multiclass: 0.5144
# Epoch 48/200
# 10/10 [==============================] - 1s 160ms/step - loss: 0.0043 - dice_coef_multiclass: 0.4853 - val_loss: 0.0397 - val_dice_coef_multiclass: 0.5019
# Epoch 49/200
# 10/10 [==============================] - 1s 132ms/step - loss: 0.0043 - dice_coef_multiclass: 0.4853 - val_loss: 0.0382 - val_dice_coef_multiclass: 0.5185
# Epoch 50/200
# 10/10 [==============================] - 2s 178ms/step - loss: 0.0044 - dice_coef_multiclass: 0.4893 - val_loss: 0.0390 - val_dice_coef_multiclass: 0.5102
# Epoch 51/200
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0042 - dice_coef_multiclass: 0.4869 - val_loss: 0.0413 - val_dice_coef_multiclass: 0.4987
# Epoch 52/200
# 10/10 [==============================] - 1s 134ms/step - loss: 0.0041 - dice_coef_multiclass: 0.4913 - val_loss: 0.0385 - val_dice_coef_multiclass: 0.5180
# Epoch 53/200
# 10/10 [==============================] - 1s 130ms/step - loss: 0.0041 - dice_coef_multiclass: 0.4872 - val_loss: 0.0386 - val_dice_coef_multiclass: 0.5001
# Epoch 54/200
# 10/10 [==============================] - 2s 217ms/step - loss: 0.0041 - dice_coef_multiclass: 0.4898 - val_loss: 0.0354 - val_dice_coef_multiclass: 0.5205
# Epoch 55/200
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0040 - dice_coef_multiclass: 0.4869 - val_loss: 0.0328 - val_dice_coef_multiclass: 0.5160
# Epoch 56/200
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0040 - dice_coef_multiclass: 0.4874 - val_loss: 0.0360 - val_dice_coef_multiclass: 0.5166
# Epoch 57/200
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0039 - dice_coef_multiclass: 0.4843 - val_loss: 0.0374 - val_dice_coef_multiclass: 0.5184
# Epoch 58/200
# 10/10 [==============================] - 2s 192ms/step - loss: 0.0039 - dice_coef_multiclass: 0.4890 - val_loss: 0.0364 - val_dice_coef_multiclass: 0.5088
# Epoch 59/200
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0038 - dice_coef_multiclass: 0.4875 - val_loss: 0.0283 - val_dice_coef_multiclass: 0.5241
# Epoch 60/200
# 10/10 [==============================] - 1s 147ms/step - loss: 0.0038 - dice_coef_multiclass: 0.4845 - val_loss: 0.0321 - val_dice_coef_multiclass: 0.5238
# Epoch 61/200
# 10/10 [==============================] - 2s 190ms/step - loss: 0.0038 - dice_coef_multiclass: 0.4874 - val_loss: 0.0287 - val_dice_coef_multiclass: 0.5273
# Epoch 62/200
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0037 - dice_coef_multiclass: 0.4846 - val_loss: 0.0320 - val_dice_coef_multiclass: 0.5321
# Epoch 63/200
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0038 - dice_coef_multiclass: 0.4848 - val_loss: 0.0336 - val_dice_coef_multiclass: 0.5276
# Epoch 64/200
# 10/10 [==============================] - 1s 139ms/step - loss: 0.0037 - dice_coef_multiclass: 0.4919 - val_loss: 0.0319 - val_dice_coef_multiclass: 0.5197
# Epoch 65/200
# 10/10 [==============================] - 2s 187ms/step - loss: 0.0037 - dice_coef_multiclass: 0.4866 - val_loss: 0.0347 - val_dice_coef_multiclass: 0.5278
# Epoch 66/200
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0037 - dice_coef_multiclass: 0.4866 - val_loss: 0.0312 - val_dice_coef_multiclass: 0.5280
# Epoch 67/200
# 10/10 [==============================] - 1s 143ms/step - loss: 0.0035 - dice_coef_multiclass: 0.4852 - val_loss: 0.0300 - val_dice_coef_multiclass: 0.5361
# Epoch 68/200
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0036 - dice_coef_multiclass: 0.4885 - val_loss: 0.0326 - val_dice_coef_multiclass: 0.5306
# Epoch 69/200
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0036 - dice_coef_multiclass: 0.4868 - val_loss: 0.0366 - val_dice_coef_multiclass: 0.5145
# Epoch 70/200
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0036 - dice_coef_multiclass: 0.4889 - val_loss: 0.0393 - val_dice_coef_multiclass: 0.5180
# Epoch 71/200
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0035 - dice_coef_multiclass: 0.4884 - val_loss: 0.0363 - val_dice_coef_multiclass: 0.5136
# Epoch 72/200
# 10/10 [==============================] - 1s 147ms/step - loss: 0.0036 - dice_coef_multiclass: 0.4869 - val_loss: 0.0535 - val_dice_coef_multiclass: 0.5158
# Epoch 73/200
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0034 - dice_coef_multiclass: 0.4889 - val_loss: 0.0360 - val_dice_coef_multiclass: 0.5213
# Epoch 74/200
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0035 - dice_coef_multiclass: 0.4895 - val_loss: 0.0433 - val_dice_coef_multiclass: 0.5083
# Epoch 75/200
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0033 - dice_coef_multiclass: 0.4911 - val_loss: 0.0377 - val_dice_coef_multiclass: 0.5167
# Epoch 76/200
# 10/10 [==============================] - 1s 144ms/step - loss: 0.0033 - dice_coef_multiclass: 0.4898 - val_loss: 0.0364 - val_dice_coef_multiclass: 0.5090
# Epoch 77/200
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0033 - dice_coef_multiclass: 0.4883 - val_loss: 0.0352 - val_dice_coef_multiclass: 0.5069
# Epoch 78/200
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0035 - dice_coef_multiclass: 0.4904 - val_loss: 0.0391 - val_dice_coef_multiclass: 0.5107
# Epoch 79/200
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0034 - dice_coef_multiclass: 0.4892 - val_loss: 0.0357 - val_dice_coef_multiclass: 0.5233
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
plt.figure(figsize=(12, 4)) 

plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.xlabel('Epoch', size=16)
plt.ylabel('Sparse Categorical \n Cross-Entropy Loss', size=16)
plt.xticks(size=12)
plt.yticks(size=12)
plt.title('Loss throughout training, \n lr={}'.format(np.round(learning_rate,5)), size=16)
plt.legend(prop={'size': 12})

# %%
plt.figure(figsize=(12, 4)) 

plt.subplot(1,2,2)
plt.plot(history.history['dice_coef_multiclass'], label='Training')
plt.plot(history.history['val_dice_coef_multiclass'], label='Validation')
plt.xlabel('Epoch', size=16)
plt.ylabel('Dice Coefficient', size=16)
plt.xticks(size=12)
plt.yticks(size=12)
plt.title('Dice Coefficient throughout training, \n lr={}'.format(np.round(learning_rate,5)), size=16)
plt.legend(prop={'size': 12})

# %% [markdown]
# # Predict on single test image

# %%
test_nonempty_gcs_pattern = "gs://vascular_multiclass_method2_step2_60/test_non_empty*"
test_nonempty_filenames = tf.io.gfile.glob(test_nonempty_gcs_pattern)

test_nonempty_ds = tf.data.TFRecordDataset(test_nonempty_filenames)
test_nonempty_ds = test_nonempty_ds.map(_parse_image_function)
test_nonempty_ds = test_nonempty_ds.map(_unpack_proto)
test_nonempty_ds = test_nonempty_ds.map(to_3_channels)

test_ds = prepare_data(test_nonempty_ds)

# %%
test_images = []
test_masks = []

for batch_num in range(4):
  for images, masks in test_ds.take(batch_num):  
        numpy_images = images.numpy()
        numpy_masks = masks.numpy()

        test_images.append(numpy_images)
        test_masks.append(numpy_masks)

test_images = np.concatenate(test_images)
test_masks = np.concatenate(test_masks)

# %%
test_images.shape, test_images[0].shape
# Out:
# ((384, 60, 60, 3), (60, 60, 3))

# %%
plt.figure(figsize=(15, 5)) 

img_num = 26

plt.subplot(1,3,1)
plt.imshow(test_images[img_num])
plt.title('Original test image', size=16)
plt.xticks(size=12)

plt.subplot(1,3,2)
plt.imshow(test_masks[img_num], cmap='gray')
plt.title('True mask', size=16)

pred_mask = model.predict(tf.expand_dims(test_images[img_num], axis=[0]))
pred_mask = tf.argmax(pred_mask, axis=-1)[0]

plt.subplot(1,3,3)
plt.imshow(pred_mask, cmap='gray')
plt.title('Predicted mask', size=16)

print('Unique pixel values in predicted mask: {}'.format(np.unique(np.round(pred_mask))))
# Out:
# Unique pixel values in predicted mask: [0 1 2]

# %%
pred_mask.shape
# Out:
# TensorShape([40, 40])

# %% [markdown]
# # Evaluate on whole test set

# %%
print('Predicting masks on test data...')
test_preds = [tf.argmax(model.predict(tf.expand_dims(image, axis=[0])), axis=-1)[0] for image in test_images]
# Out:
# Predicting masks on test data...

# %%
len(test_preds), test_preds[0].shape
# Out:
# (384, TensorShape([60, 60]))

# %%
def compare_img_mask(img_num):

  """
  Display original image with mask, true mask and predicted mask for a specified image number
  
  Args:
  train_, test_ or valid_ + images/masks/preds
  """
  
  plt.figure(figsize=(20, 4)) 

  plt.subplot(1,3,1)
  plt.imshow(test_images[img_num])
  plt.title('Original image patch', size=16)

  plt.subplot(1,3,2)
  plt.imshow(test_masks[img_num], cmap='gray')
  plt.title('True mask (60 x 60)', size=16)

  plt.subplot(1,3,3)
  plt.imshow(test_preds[img_num], cmap='gray')
  plt.title('Predicted mask (60 x 60)', size=16)

# %%
compare_img_mask(5)

# %% [markdown]
# ## Dice Coefficient: Aneurysms & vessels

# %%
def test_dice_multiclass(y_true, y_pred, output_channels, smooth=1e-15):
  dice_tot = 0

  for index in range(1, output_channels): # calculate dice coefficient for classes 1 & 2 (aneurysms & vasculature, not background)

        intersection = np.sum((y_true==index) * (y_pred==index))

        num = (2* intersection + smooth)

        denom = (np.sum(y_true==index) + np.sum(y_pred==index) + smooth)

        dice_tot += num/denom

  return dice_tot/(output_channels-1) # take average dice

# %%
# calculate dice coeff for each pair of true (test_masks) and predicted (test_preds) masks in the test set

dice_coeff_list = []
dice_coeff_dict = {}

for i in range(len(test_masks)):
  true_mask = test_masks[i]
  pred_mask = test_preds[i]
  a = tf.make_tensor_proto(pred_mask)
  pred_mask = tf.make_ndarray(a)

  dice_coeff = test_dice_multiclass(true_mask, pred_mask, 3)
  dice_coeff = np.array(dice_coeff)
  dice_coeff_list.append(dice_coeff)
  dice_coeff_dict[i] = dice_coeff

np.mean(dice_coeff_list), np.std(dice_coeff_list)
# Out:
# (0.38887867773305934, 0.1776752071412881)

# %%
plt.hist(dice_coeff_list)
plt.title('Distribution of Dice Coefficient Scores \n over Test set (for aneurysms & vessels)\n lr = {}'.format(np.round(learning_rate,5)), size=16)
plt.xlabel('Dice Coefficient Score', size=16)
plt.ylabel('Number of Images', size=16)
plt.xticks(size=14)
plt.yticks(size=14)

plt.xlim(0, 1)
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Dice Coefficient: aneurysms only

# %%
def test_dice_multiclass2(y_true, y_pred, output_channels, smooth=1e-15):
  dice_tot = 0

  index = 2

  intersection = np.sum((y_true==index) * (y_pred==index))

  num = (2* intersection + smooth)

  denom = (np.sum(y_true==index) + np.sum(y_pred==index) + smooth)

  dice_tot += num/denom

  return dice_tot# take average dice

# %%
# calculate dice coeff for each pair of true (test_masks) and predicted (test_preds) masks in the test set

dice_coeff_list2 = []
dice_coeff_dict2 = {}

for i in range(len(test_masks)):
  true_mask = test_masks[i]
  pred_mask = test_preds[i]
  a = tf.make_tensor_proto(pred_mask)
  pred_mask = tf.make_ndarray(a)

  dice_coeff = test_dice_multiclass2(true_mask, pred_mask, 3)
  dice_coeff = np.array(dice_coeff)
  dice_coeff_list2.append(dice_coeff)
  dice_coeff_dict2[i] = dice_coeff

np.mean(dice_coeff_list2), np.std(dice_coeff_list2)
# Out:
# (0.2528640370538173, 0.28458845552029194)

# %%
plt.hist(dice_coeff_list2)
plt.title('Distribution of Dice Coefficient Scores \n over Test set (for aneurysms only) \n lr = {}'.format(np.round(learning_rate,5)), size=16)
plt.xlabel('Dice Coefficient Score', size=16)
plt.ylabel('Number of Images', size=16)
plt.xticks(size=14)
plt.yticks(size=14)

plt.xlim(0, 1)
plt.ylim(0, 300)
# Out:
# (0.0, 300.0)

# %%
# create lists 'low' and 'high' that store indices of low and high scoring masks respectively

low = []
med = []
high = []

for key,val in dice_coeff_dict.items():
  if val<0.3:
    low.append(key)
  elif val<0.7 and val>0.4:
    med.append(key)
  elif val>0.7:
    high.append(key)

len(low), len(med), len(high)
# Out:
# (80, 178, 21)

# %%
compare_img_mask(191)

# %%
compare_img_mask(66)

# %%
compare_img_mask(129)

# %%
compare_img_mask(126)

# %%
for i in low:
  print(i)
  compare_img_mask(i)
  plt.show()
# Out:
# 2
# 6
# 9
# 10
# 19
# 20
# 24
# 36
# 45
# 49
# 52
# 55
# 62
# 64
# 67
# 72
# 75
# 77
# 90
# 91
# 94
# 104
# 105
# 108
# 109
# 110
# 115
# 119
# 123
# 136
# 143
# 144
# 146
# 160
# 161
# 170
# 172
# 187
# 189
# 199
# 201
# 205
# 223
# 232
# 235
# 241
# 246
# 247
# 264
# 273
# 279
# 281
# 282
# 285
# 287
# 294
# 295
# 296
# 301
# 303
# 314
# 315
# 316
# 319
# 323
# 324
# 326
# 329
# 331
# 332
# 336
# 342
# 350
# 356
# 360
# 365
# 367
# 375
# 377
# 378

# %%
compare_img_mask(279)

# %% [markdown]
# ## Hausdorff Distance: aneurysms only

# %%
# calculate hausdorff dist for each pair of true (test_masks) and predicted (test_preds) masks in the test set

hausdorff_list = []
hausdorff_dict = {}

for i in range(len(test_masks)):
  true_mask = test_masks[i]
  pred_mask = test_preds[i]
  a = tf.make_tensor_proto(pred_mask)
  pred_mask = tf.make_ndarray(a)

  hausdorff_dist = directed_hausdorff(true_mask, pred_mask)[0]
  hausdorff_list.append(hausdorff_dist)
  hausdorff_dict[i] = hausdorff_dist

np.mean(hausdorff_list), np.std(hausdorff_list)
# Out:
# (2.4420211130734693, 0.9615371634194637)

# %%
plt.hist(hausdorff_list)
plt.title('Distribution of Hausdorff Distances \n over Test set (aneurysms only) \n lr = {}'.format(np.round(learning_rate,5)), size=16)
plt.xlabel('Hausdorff Distance', size=16)
plt.ylabel('Number of Images', size=16)
plt.xticks(size=14)
plt.yticks(size=14)

plt.xlim(0, 10)
plt.ylim(0, 200)
# Out:
# (0.0, 200.0)

# %%
# create lists 'low' and 'high' that store indices of low and high scoring masks respectively

low_h = []
med_h = []
high_h = []

for key,val in hausdorff_dict.items():
  if val<2:
    low_h.append(key)
  elif val<4 and val>2:
    med_h.append(key)
  elif val>4:
    high_h.append(key)

len(low_h), len(med_h), len(high_h)
# Out:
# (134, 162, 30)

# %%
low_h, med_h, high_h

# %%
compare_img_mask(16)
